# %%
# Install Google OR-Tools
# %pip install ortools
# Out:
# Collecting ortools
#   Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_26_aarch64.manylinux_2_28_aarch64.whl.metadata (3.3 kB)
# Collecting absl-py>=2.0.0 (from ortools)
#   Downloading absl_py-2.4.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=2.0.2 in /databricks/python3/lib/python3.12/site-packages (from ortools) (2.1.3)
# Requirement already satisfied: pandas>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from ortools) (2.2.3)
# Collecting protobuf<6.34,>=6.33.1 (from ortools)
#   Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_aarch64.whl.metadata (593 bytes)
# Requirement already satisfied: typing-extensions>=4.12 in /databricks/python3/lib/python3.12/site-packages (from ortools) (4.12.2)
# Collecting immutabledict>=3.0.0 (from ortools)
#   Downloading immutabledict-4.3.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /databricks/python3/lib/python3.12/site-packages (from pandas>=2.0.0->ortools) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->ortools) (1.16.0)
# Downloading ortools-9.15.6755-cp312-cp312-manylinux_2_26_aarch64.manylinux_2_28_aarch64.whl (27.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.6/27.6 MB 42.5 MB/s eta 0:00:00
# Downloading absl_py-2.4.0-py3-none-any.whl (135 kB)
# Downloading immutabledict-4.3.1-py3-none-any.whl (5.0 kB)
# Downloading protobuf-6.33.6-cp39-abi3-manylinux2014_aarch64.whl (324 kB)
# Installing collected packages: protobuf, immutabledict, absl-py, ortools
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Not uninstalling protobuf at /databricks/python3/lib/python3.12/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-b77b869c-d31a-4af0-aa25-7c20854e9b7c
#     Can't uninstall 'protobuf'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.20.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.19.5, but you have protobuf 6.33.6 which is incompatible.
# googleapis-common-protos 1.65.0 requires protobuf!=3.20.0,!=3.20.1,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0.dev0,>=3.20.2, but you have protobuf 6.33.6 which is incompatible.
# grpcio-status 1.67.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 6.33.6 which is incompatible.
# Successfully installed absl-py-2.4.0 immutabledict-4.3.1 ortools-9.15.6755 protobuf-6.33.6
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from ortools.linear_solver import pywraplp

# Instantiate a Glop solver
solver = pywraplp.Solver.CreateSolver("GLOP")

# Create the two variables (non-negative)
x = solver.NumVar(0, solver.infinity(), "x")
y = solver.NumVar(0, solver.infinity(), "y")

# Constraint 0: x + 2y <= 14.
solver.Add(x + 2 * y <= 14.0)

# Constraint 1: 3x - y >= 0.
solver.Add(3 * x - y >= 0.0)

# Constraint 2: x - y <= 2.
solver.Add(x - y <= 2.0)

# Objective function: Maximize 3x + 4y.
solver.Maximize(3 * x + 4 * y)

# Solve the model and print results.
status = solver.Solve()

if status == pywraplp.Solver.OPTIMAL:
    print("Solution:")
    print(f"Objective value = {solver.Objective().Value():0.1f}")
    print(f"x = {x.solution_value():0.1f}")
    print(f"y = {y.solution_value():0.1f}")
else:
    print("The problem does not have an optimal solution.")
# Out:
# Solution:
# Objective value = 34.0
# x = 6.0
# y = 4.0
